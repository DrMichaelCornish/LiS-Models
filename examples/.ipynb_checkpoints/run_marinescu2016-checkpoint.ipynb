# %%
import os
os.chdir('../') # insures use of models folder as python module 
# Any figures saved or data pickled in the current working 
# directly will be saved up one folder from here.
import pybamm
import models
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# %%
model = models.Marinescu2016()

# %%
model.print_citations()
# Out:
# H1. Marinescu, M., Zhang, T. & Offer, G. J. A zero dimensional model of lithium-sulfur batteries during charge and discharge. Phys. Chem. Chem. Phys. 18, 584–593 (2016).

# %%
experiment = pybamm.Experiment(['Discharge at 1.7 A until 2.24V'])

sim = pybamm.Simulation(
    model=model,
    experiment = experiment,
    solver=pybamm.CasadiSolver(
        atol=1e-12,
        rtol=1e-12,
        max_step_decrease_count = 15,
    ),
)

# %%
sim.solve()
# Out:
# Newton/Linesearch algorithm failed to converge.
# Newton/Linesearch algorithm failed to converge.
# Newton/Linesearch algorithm failed to converge.
# At t = 7117.87 and h = 1.70259e-14, the error test failed repeatedly or with |h| = hmin.
# At t = 7117.87 and h = 1.70273e-14, the error test failed repeatedly or with |h| = hmin.
# At t = 7117.87 and h = 1.70302e-14, the error test failed repeatedly or with |h| = hmin.
# At t = 7117.87 and h = 1.70358e-14, the error test failed repeatedly or with |h| = hmin.
# At t = 7117.87 and h = 1.70509e-14, the error test failed repeatedly or with |h| = hmin.

# %%
# See figure 3(a) of Marinescu et al. (2016)
capacity = sim.solution['Capacity [Ah]'].entries
V = sim.solution["Terminal voltage [V]"].entries
plt.plot(capacity, V)

plt.legend(["0.5C",])
plt.xlabel('Capacity [Ah]')
plt.ylabel('Voltage [V]');
